# %%
import pandas as pd
from IPython.display import display
from matplotlib.pyplot import ylabel, figure

# Cấu trúc lại dictionary để các key là tên cột và các value là dữ liệu
data = {
    'Author': ['Pham Dinh Khanh'],
    'Book': ['ML algorithms to Practice'],
    'Target': ['Vi mot cong dong AI vung manh hon'],
    'No_Donation': ['Community']
}

df = pd.DataFrame(data)
display(df)
# Out:
#             Author                       Book  \
# 0  Pham Dinh Khanh  ML algorithms to Practice
#
#                               Target No_Donation
# 0  Vi mot cong dong AI vung manh hon   Community

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/phamdinhkhanh/datasets/master/BostonHousing.csv", sep=",", header = 0, index_col = None)
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
# Check for datatype
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
# Thong ke mo ta so lieu
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# %%script echo skipping
#
# # Lưu dữ liệu sang file csv
# df.to_csv('BostonHousing.csv', index = False)
# # Lưu file excel
# df.to_excel('BostonHousing.xls', index = False)
# # Lưu dữ file json
# df.to_json('BostonHousing.json') #do not include index = False, index only use for table orient
# Out:
# skipping

# %%
# Lua chon 5 dong dau va 5 cot dau cua df
df.iloc[:5,:5]
# Out:
#       crim    zn  indus  chas    nox
# 0  0.00632  18.0   2.31     0  0.538
# 1  0.02731   0.0   7.07     0  0.469
# 2  0.02729   0.0   7.07     0  0.469
# 3  0.03237   0.0   2.18     0  0.458
# 4  0.06905   0.0   2.18     0  0.458

# %%
df.iloc[5:10,2:4]
# Out:
#    indus  chas
# 5   2.18     0
# 6   7.87     0
# 7   7.87     0
# 8   7.87     0
# 9   7.87     0

# %%
df.loc[10:15]
# Out:
#        crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 10  0.22489  12.5   7.87     0  0.524  6.377  94.3  6.3467    5  311     15.2
# 11  0.11747  12.5   7.87     0  0.524  6.009  82.9  6.2267    5  311     15.2
# 12  0.09378  12.5   7.87     0  0.524  5.889  39.0  5.4509    5  311     15.2
# 13  0.62976   0.0   8.14     0  0.538  5.949  61.8  4.7075    4  307     21.0
# 14  0.63796   0.0   8.14     0  0.538  6.096  84.5  4.4619    4  307     21.0
# 15  0.62739   0.0   8.14     0  0.538  5.834  56.5  4.4986    4  307     21.0
#
#          b  lstat  medv
# 10  392.52  20.45  15.0
# 11  396.90  13.27  18.9
# 12  390.50  15.71  21.7
# 13  396.90   8.26  20.4
# 14  380.02  10.26  18.2
# 15  395.62   8.47  19.9

# %%
df[['crim','tax','rad']].head()
# Out:
#       crim  tax  rad
# 0  0.00632  296    1
# 1  0.02731  242    2
# 2  0.02729  242    2
# 3  0.03237  222    3
# 4  0.06905  222    3

# %%
df[['crim','tax','rad']].iloc[:5,:5]
# Out:
#       crim  tax  rad
# 0  0.00632  296    1
# 1  0.02731  242    2
# 2  0.02729  242    2
# 3  0.03237  222    3
# 4  0.06905  222    3

# %%
df[df['rm'] > 4].head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df[(df['rm']>4) & (df['tax']>250)].head()
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 6  395.60  12.43  22.9
# 7  396.90  19.15  27.1
# 8  386.63  29.93  16.5
# 9  386.71  17.10  18.9

# %%
df.select_dtypes('float').head()
# Out:
#       crim    zn  indus    nox     rm   age     dis  ptratio       b  lstat  \
# 0  0.00632  18.0   2.31  0.538  6.575  65.2  4.0900     15.3  396.90   4.98
# 1  0.02731   0.0   7.07  0.469  6.421  78.9  4.9671     17.8  396.90   9.14
# 2  0.02729   0.0   7.07  0.469  7.185  61.1  4.9671     17.8  392.83   4.03
# 3  0.03237   0.0   2.18  0.458  6.998  45.8  6.0622     18.7  394.63   2.94
# 4  0.06905   0.0   2.18  0.458  7.147  54.2  6.0622     18.7  396.90   5.33
#
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
df2 = pd.DataFrame({
    'name':['a', 'b', 'c', 'd', 'e'],
    'age_1':[1, 2, 3, 4, 5],
    'age_2':[3, 5, 7, 9 , 10],
    'age_3':[2, 5, 2, 5, 6]
})

df2.head()
# Out:
#   name  age_1  age_2  age_3
# 0    a      1      3      2
# 1    b      2      5      5
# 2    c      3      7      2
# 3    d      4      9      5
# 4    e      5     10      6

# %%
df2.filter(regex='^age',axis=1)
# Out:
#    age_1  age_2  age_3
# 0      1      3      2
# 1      2      5      5
# 2      3      7      2
# 3      4      9      5
# 4      5     10      6

# %%
# Sort data
df.sort_values('medv',ascending=False).head()
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 369  5.66998  0.0   18.1     1  0.631  6.683   96.8  1.3567   24  666
# 372  8.26725  0.0   18.1     1  0.668  5.875   89.6  1.1296   24  666
# 371  9.23230  0.0   18.1     0  0.631  6.216  100.0  1.1691   24  666
# 370  6.53876  0.0   18.1     1  0.631  7.016   97.5  1.2024   24  666
# 368  4.89822  0.0   18.1     0  0.631  4.970  100.0  1.3325   24  666
#
#      ptratio       b  lstat  medv
# 369     20.2  375.33   3.73  50.0
# 372     20.2  347.88   8.88  50.0
# 371     20.2  366.15   9.53  50.0
# 370     20.2  392.05   2.96  50.0
# 368     20.2  375.52   3.26  50.0

# %%
df.sort_values(['medv','tax'],ascending=False).head()
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 368  4.89822  0.0   18.1     0  0.631  4.970  100.0  1.3325   24  666
# 369  5.66998  0.0   18.1     1  0.631  6.683   96.8  1.3567   24  666
# 370  6.53876  0.0   18.1     1  0.631  7.016   97.5  1.2024   24  666
# 371  9.23230  0.0   18.1     0  0.631  6.216  100.0  1.1691   24  666
# 372  8.26725  0.0   18.1     1  0.668  5.875   89.6  1.1296   24  666
#
#      ptratio       b  lstat  medv
# 368     20.2  375.52   3.26  50.0
# 369     20.2  375.33   3.73  50.0
# 370     20.2  392.05   2.96  50.0
# 371     20.2  366.15   9.53  50.0
# 372     20.2  347.88   8.88  50.0

# %%
# min, max, mean, median, sum
print(df['tax'].min(), df['tax'].max(), df['tax'].mean(), df['tax'].median(), df['tax'].sum())
# Out:
# 187 711 408.2371541501976 330.0 206568

# %%
import numpy as np

labels = ['low', 'normal', 'high']
tax_labels = pd.qcut(df['tax'], q=3, labels=labels)
np.unique(tax_labels, return_counts = True)
# Out:
# (array(['high', 'low', 'normal'], dtype=object), array([168, 172, 166]))

# %%
df['tax'].plot()
# Out:
# <Axes: >

# %%
df['tax'].plot(marker='o')
# Out:
# <Axes: >

# %%
df5 = pd.DataFrame({
  'Ho':['Pham','Nguyen'],
  'Ten' :['Cong', 'Dong'],
  'ChieuCao':[170, 175],
  'CanNang':[60, 65],
  'Tuoi': [25, 27],
  'Diem': [8.5, 9.0],
})

df5
# Out:
#        Ho   Ten  ChieuCao  CanNang  Tuoi  Diem
# 0    Pham  Cong       170       60    25   8.5
# 1  Nguyen  Dong       175       65    27   9.0

# %%
df5.melt(['Ho', 'Ten'])
# Out:
#        Ho   Ten  variable  value
# 0    Pham  Cong  ChieuCao  170.0
# 1  Nguyen  Dong  ChieuCao  175.0
# 2    Pham  Cong   CanNang   60.0
# 3  Nguyen  Dong   CanNang   65.0
# 4    Pham  Cong      Tuoi   25.0
# 5  Nguyen  Dong      Tuoi   27.0
# 6    Pham  Cong      Diem    8.5
# 7  Nguyen  Dong      Diem    9.0

# %%
df5
# Out:
#        Ho   Ten  ChieuCao  CanNang  Tuoi  Diem
# 0    Pham  Cong       170       60    25   8.5
# 1  Nguyen  Dong       175       65    27   9.0

# %%
pd.get_dummies(df5)
# Out:
#    ChieuCao  CanNang  Tuoi  Diem  Ho_Nguyen  Ho_Pham  Ten_Cong  Ten_Dong
# 0       170       60    25   8.5      False     True      True     False
# 1       175       65    27   9.0       True    False     False      True

# %%
import pandas as pd

df_sinhvien = pd.DataFrame({
    'ID':['001', '002', '003', '004', '005'],
    'Name':['Pham Van Nghia', 'Tong Thuy Linh', 'Le Van Dai', 'Tran Quang Nghia', 'Doan Thu Ha'],
    'Age': [25, 26, 25, 23, 22],
    'Province':['Nam Dinh', 'Thanh Hoa', 'TP Ho Chi Minh', 'Da Nang', 'Can Tho']
})

df_sinhvien
# Out:
#     ID              Name  Age        Province
# 0  001    Pham Van Nghia   25        Nam Dinh
# 1  002    Tong Thuy Linh   26       Thanh Hoa
# 2  003        Le Van Dai   25  TP Ho Chi Minh
# 3  004  Tran Quang Nghia   23         Da Nang
# 4  005       Doan Thu Ha   22         Can Tho

# %%
df_score = pd.DataFrame({
    'ID': ['001', '002', '003', '006', '007'],
    'Math': [6.75, 9, 8, 7, 10],
    'Physic': [8, 9, 9, 8.5, 9],
    'Chemistry': [7, 9.5, 7.5, 9, 10],
    'Province': ['Nam Dinh', 'Thanh Hoa', 'TP Ho Chi Minh', 'Quang Nam', 'Nghe An']
})

df_score
# Out:
#     ID   Math  Physic  Chemistry        Province
# 0  001   6.75     8.0        7.0        Nam Dinh
# 1  002   9.00     9.0        9.5       Thanh Hoa
# 2  003   8.00     9.0        7.5  TP Ho Chi Minh
# 3  006   7.00     8.5        9.0       Quang Nam
# 4  007  10.00     9.0       10.0         Nghe An

# %%
pd.merge(df_sinhvien, df_score,
         left_on='ID',
         right_on='ID',
         how='inner',
         suffixes=['_Sv', '_Score'])
# Out:
#     ID            Name  Age     Province_Sv  Math  Physic  Chemistry  \
# 0  001  Pham Van Nghia   25        Nam Dinh  6.75     8.0        7.0
# 1  002  Tong Thuy Linh   26       Thanh Hoa  9.00     9.0        9.5
# 2  003      Le Van Dai   25  TP Ho Chi Minh  8.00     9.0        7.5
#
#    Province_Score
# 0        Nam Dinh
# 1       Thanh Hoa
# 2  TP Ho Chi Minh

# %%
pd.merge(df_sinhvien, df_score,
         left_on='ID',
         right_on='ID',
         how='left',
         suffixes=['_Sv', '_Score'])
# Out:
#     ID              Name  Age     Province_Sv  Math  Physic  Chemistry  \
# 0  001    Pham Van Nghia   25        Nam Dinh  6.75     8.0        7.0
# 1  002    Tong Thuy Linh   26       Thanh Hoa  9.00     9.0        9.5
# 2  003        Le Van Dai   25  TP Ho Chi Minh  8.00     9.0        7.5
# 3  004  Tran Quang Nghia   23         Da Nang   NaN     NaN        NaN
# 4  005       Doan Thu Ha   22         Can Tho   NaN     NaN        NaN
#
#    Province_Score
# 0        Nam Dinh
# 1       Thanh Hoa
# 2  TP Ho Chi Minh
# 3             NaN
# 4             NaN

# %%
pd.merge(df_sinhvien, df_score,
         left_on='ID',
         right_on='ID',
         how='right',
         suffixes=['_Sv', '_Score'])
# Out:
#     ID            Name   Age     Province_Sv   Math  Physic  Chemistry  \
# 0  001  Pham Van Nghia  25.0        Nam Dinh   6.75     8.0        7.0
# 1  002  Tong Thuy Linh  26.0       Thanh Hoa   9.00     9.0        9.5
# 2  003      Le Van Dai  25.0  TP Ho Chi Minh   8.00     9.0        7.5
# 3  006             NaN   NaN             NaN   7.00     8.5        9.0
# 4  007             NaN   NaN             NaN  10.00     9.0       10.0
#
#    Province_Score
# 0        Nam Dinh
# 1       Thanh Hoa
# 2  TP Ho Chi Minh
# 3       Quang Nam
# 4         Nghe An

# %%
pd.merge(df_sinhvien, df_score,
         left_on='ID',
         right_on='ID',
         how='outer',
         suffixes=['_Sv', '_Score'])
# Out:
#     ID              Name   Age     Province_Sv   Math  Physic  Chemistry  \
# 0  001    Pham Van Nghia  25.0        Nam Dinh   6.75     8.0        7.0
# 1  002    Tong Thuy Linh  26.0       Thanh Hoa   9.00     9.0        9.5
# 2  003        Le Van Dai  25.0  TP Ho Chi Minh   8.00     9.0        7.5
# 3  004  Tran Quang Nghia  23.0         Da Nang    NaN     NaN        NaN
# 4  005       Doan Thu Ha  22.0         Can Tho    NaN     NaN        NaN
# 5  006               NaN   NaN             NaN   7.00     8.5        9.0
# 6  007               NaN   NaN             NaN  10.00     9.0       10.0
#
#    Province_Score
# 0        Nam Dinh
# 1       Thanh Hoa
# 2  TP Ho Chi Minh
# 3             NaN
# 4             NaN
# 5       Quang Nam
# 6         Nghe An

# %%
df_sinhvien.join(df_score, lsuffix='_Sv', rsuffix='_Score')
# Out:
#   ID_Sv              Name  Age     Province_Sv ID_Score   Math  Physic  \
# 0   001    Pham Van Nghia   25        Nam Dinh      001   6.75     8.0
# 1   002    Tong Thuy Linh   26       Thanh Hoa      002   9.00     9.0
# 2   003        Le Van Dai   25  TP Ho Chi Minh      003   8.00     9.0
# 3   004  Tran Quang Nghia   23         Da Nang      006   7.00     8.5
# 4   005       Doan Thu Ha   22         Can Tho      007  10.00     9.0
#
#    Chemistry  Province_Score
# 0        7.0        Nam Dinh
# 1        9.5       Thanh Hoa
# 2        7.5  TP Ho Chi Minh
# 3        9.0       Quang Nam
# 4       10.0         Nghe An

# %%
# Thiết lập index
df_sinhvien.set_index('ID', inplace = True)
df_score.set_index('ID', inplace = True)

# Join bảng
df_sinhvien.join(df_score, lsuffix='_Sv', rsuffix='_Score')
# Out:
#                  Name  Age     Province_Sv  Math  Physic  Chemistry  \
# ID
# 001    Pham Van Nghia   25        Nam Dinh  6.75     8.0        7.0
# 002    Tong Thuy Linh   26       Thanh Hoa  9.00     9.0        9.5
# 003        Le Van Dai   25  TP Ho Chi Minh  8.00     9.0        7.5
# 004  Tran Quang Nghia   23         Da Nang   NaN     NaN        NaN
# 005       Doan Thu Ha   22         Can Tho   NaN     NaN        NaN
#
#      Province_Score
# ID
# 001        Nam Dinh
# 002       Thanh Hoa
# 003  TP Ho Chi Minh
# 004             NaN
# 005             NaN

# %%
# reset lại index
df_sinhvien.reset_index('ID', inplace = True)
df_score.reset_index('ID', inplace = True)

# %%
pd.concat([df_sinhvien, df_score],
          axis=0,
          join='inner')
# Out:
#     ID        Province
# 0  001        Nam Dinh
# 1  002       Thanh Hoa
# 2  003  TP Ho Chi Minh
# 3  004         Da Nang
# 4  005         Can Tho
# 0  001        Nam Dinh
# 1  002       Thanh Hoa
# 2  003  TP Ho Chi Minh
# 3  006       Quang Nam
# 4  007         Nghe An

# %%
pd.concat([df_sinhvien, df_score],
          axis=0,
          join='outer')
# Out:
#     ID              Name   Age        Province   Math  Physic  Chemistry
# 0  001    Pham Van Nghia  25.0        Nam Dinh    NaN     NaN        NaN
# 1  002    Tong Thuy Linh  26.0       Thanh Hoa    NaN     NaN        NaN
# 2  003        Le Van Dai  25.0  TP Ho Chi Minh    NaN     NaN        NaN
# 3  004  Tran Quang Nghia  23.0         Da Nang    NaN     NaN        NaN
# 4  005       Doan Thu Ha  22.0         Can Tho    NaN     NaN        NaN
# 0  001               NaN   NaN        Nam Dinh   6.75     8.0        7.0
# 1  002               NaN   NaN       Thanh Hoa   9.00     9.0        9.5
# 2  003               NaN   NaN  TP Ho Chi Minh   8.00     9.0        7.5
# 3  006               NaN   NaN       Quang Nam   7.00     8.5        9.0
# 4  007               NaN   NaN         Nghe An  10.00     9.0       10.0

# %%
pd.concat([df_sinhvien, df_score],
          axis=1)
# Out:
#     ID              Name  Age        Province   ID   Math  Physic  Chemistry  \
# 0  001    Pham Van Nghia   25        Nam Dinh  001   6.75     8.0        7.0
# 1  002    Tong Thuy Linh   26       Thanh Hoa  002   9.00     9.0        9.5
# 2  003        Le Van Dai   25  TP Ho Chi Minh  003   8.00     9.0        7.5
# 3  004  Tran Quang Nghia   23         Da Nang  006   7.00     8.5        9.0
# 4  005       Doan Thu Ha   22         Can Tho  007  10.00     9.0       10.0
#
#          Province
# 0        Nam Dinh
# 1       Thanh Hoa
# 2  TP Ho Chi Minh
# 3       Quang Nam
# 4         Nghe An

# %%
pd.concat([df_sinhvien.set_index('ID'), df_score.set_index('ID')],
          axis=1)
# Out:
#                  Name   Age        Province   Math  Physic  Chemistry  \
# ID
# 001    Pham Van Nghia  25.0        Nam Dinh   6.75     8.0        7.0
# 002    Tong Thuy Linh  26.0       Thanh Hoa   9.00     9.0        9.5
# 003        Le Van Dai  25.0  TP Ho Chi Minh   8.00     9.0        7.5
# 004  Tran Quang Nghia  23.0         Da Nang    NaN     NaN        NaN
# 005       Doan Thu Ha  22.0         Can Tho    NaN     NaN        NaN
# 006               NaN   NaN             NaN   7.00     8.5        9.0
# 007               NaN   NaN             NaN  10.00     9.0       10.0
#
#            Province
# ID
# 001        Nam Dinh
# 002       Thanh Hoa
# 003  TP Ho Chi Minh
# 004             NaN
# 005             NaN
# 006       Quang Nam
# 007         Nghe An

# %%
pd.concat([df_sinhvien, df_score],
          axis=1,
          join='inner')
# Out:
#     ID              Name  Age        Province   ID   Math  Physic  Chemistry  \
# 0  001    Pham Van Nghia   25        Nam Dinh  001   6.75     8.0        7.0
# 1  002    Tong Thuy Linh   26       Thanh Hoa  002   9.00     9.0        9.5
# 2  003        Le Van Dai   25  TP Ho Chi Minh  003   8.00     9.0        7.5
# 3  004  Tran Quang Nghia   23         Da Nang  006   7.00     8.5        9.0
# 4  005       Doan Thu Ha   22         Can Tho  007  10.00     9.0       10.0
#
#          Province
# 0        Nam Dinh
# 1       Thanh Hoa
# 2  TP Ho Chi Minh
# 3       Quang Nam
# 4         Nghe An

# %%
import numpy as np
import random
import string

df_chungkhoan = pd.DataFrame(columns = ['Nganh', 'Interest'])

for i in range(5):
  r = np.random.uniform(-0.01, 0.01)
  nganh = random.choice(string.ascii_lowercase)
  df_sector = pd.DataFrame({'Nganh': [nganh], 'Interest': [r]}, index=[i])
  df_chungkhoan = df_chungkhoan.append(df_sector)

df_chungkhoan
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21564\1272107720.py in ?()
#       7 for i in range(5):
#       8   r = np.random.uniform(-0.01, 0.01)
#       9   nganh = random.choice(string.ascii_lowercase)
#      10   df_sector = pd.DataFrame({'Nganh': [nganh], 'Interest': [r]}, index=[i])
# ---> 11   df_chungkhoan = df_chungkhoan.append(df_sector)
#      12
#      13 df_chungkhoan
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# ...

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/phamdinhkhanh/datasets/master/Churn_Modelling.csv",sep=",", header = 0, index_col = None)
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.groupby("Geography")["CreditScore"].mean()
# Out:
# Geography
# France     649.668329
# Germany    651.453567
# Spain      651.333872
# Name: CreditScore, dtype: float64

# %%
df["AgeGroup"] = pd.qcut(df["Age"],5,labels=["Nhóm 1","Nhóm 2","Nhóm 3","Nhóm 4","Nhóm 5"])
print(df[["Age","AgeGroup"]].head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df["AgeGroup"] = pd.qcut(df["Age"],5,labels=["Nhóm 1","Nhóm 2","Nhóm 3","Nhóm 4","Nhóm 5"])
#       2 print(df[["Age","AgeGroup"]].head(10))# Vẽ biểu đồ bar bằng pandas
#       3 df["AgeGroup"].value_counts().sort_index().plot.bar()
#
# NameError: name 'pd' is not defined

# %%
# Vẽ biểu đồ bar bằng pandas
df["AgeGroup"].value_counts().sort_index().plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Vẽ biểu đồ bar bằng pandas
# ----> 2 df["AgeGroup"].value_counts().sort_index().plot.bar()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df_iris = pd.read_csv("https://raw.githubusercontent.com/phamdinhkhanh/datasets/master/iris_train.csv", header=0, index_col=None)
df_iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           4.7          3.2           1.3          0.2  setosa
# 1           5.0          3.6           1.4          0.2  setosa
# 2           5.4          3.9           1.7          0.4  setosa
# 3           4.6          3.4           1.4          0.3  setosa
# 4           4.9          3.1           1.5          0.1  setosa

# %%
df_iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    105.000000   105.000000    105.000000    105.00000
# mean       5.812381     3.076190      3.726667      1.18381
# std        0.784305     0.455843      1.749080      0.74616
# min        4.400000     2.200000      1.000000      0.10000
# 25%        5.200000     2.800000      1.600000      0.30000
# 50%        5.700000     3.000000      4.200000      1.30000
# 75%        6.300000     3.400000      5.100000      1.80000
# max        7.900000     4.400000      6.900000      2.50000

# %%
import numpy as np
df_summary = df_iris[['Species','Petal.Length']].groupby('Species').mean()
x , y = list(df_summary.index), df_summary['Petal.Length'].values
print(x)
print(y)
# Out:
# ['setosa', 'versicolor', 'virginica']
# [1.47142857 4.18285714 5.52571429]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (16,8))
plt.bar(x,y)
plt.xlabel('Species',fontsize=16)
plt.ylabel('cm',fontsize=16)
plt.title("Average Number of Petals per Species",fontsize=18)
# Out:
# Text(0.5, 1.0, 'Average Number of Petals per Species')

# %%
# Bieu do line

# Ve bieu do line do dai trung binh giua cac canh hoa

plt.figure(figsize = (16,8))
plt.plot(x,y,marker='o',markersize=10,linestyle='-.',linewidth=2)
plt.xlabel("Species",fontsize=16)
plt.ylabel("cm",fontsize=16)
plt.title("Average Number of Petals per Species",fontsize=18)
# Out:
# Text(0.5, 1.0, 'Average Number of Petals per Species')

# %%
# Ve bieu do barchart

plt.figure(figsize = (16,8))
plt.bar(x,y)
plt.plot(x,y,marker='o',markersize=10,linestyle='-.',linewidth=2)
plt.xlabel("Species",fontsize=16)
plt.ylabel("cm",fontsize=16)
plt.title("Average Number of Petals per Species",fontsize=18)
# Out:
# Text(0.5, 1.0, 'Average Number of Petals per Species')

# %%
# Thong ke cac loai hoa

x,y = np.unique(df_iris['Species'],return_counts=True)
print(x)
print(y)
# Out:
# ['setosa' 'versicolor' 'virginica']
# [35 35 35]

# %%
#Ve bieu do line do dai canh hoa trung binh giua cac loai hoa
plt.figure(figsize = (16,8))
plt.pie(y,
        labels = x, #Nhan cua cac nhom
        colors = ['green', 'red','blue'], #Mau sac hien thi giua cac nhom
        autopct = '%1.1f%%', #Format hien thi gia tri %
        shadow = True)
plt.title("Average Number of Petals per Species",fontsize=18)
# Out:
# Text(0.5, 1.0, 'Average Number of Petals per Species')

# %%
# Lay x,y
x = df_iris['Petal.Length'].values
y = df_iris['Petal.Width'].values

# Ve bieu do scatter
plt.figure(figsize = (16,8))
plt.scatter(x,y,color = 'blue')
plt.xlabel("Petal Length",fontsize=16)
plt.ylabel("Petal Width",fontsize=16)
plt.title("Average Number of Petals per Species",fontsize=18)
# Out:
# Text(0.5, 1.0, 'Average Number of Petals per Species')

# %%
colors = {'setosa':'blue','versicolor' : 'green' ,'virginica':'red'}
for species,color in colors.items():
    subset = df_iris[df_iris['Species'] == species]
    plt.scatter(subset['Petal.Length'], subset['Petal.Width'], c=color, label=species)

# %%
import seaborn as sns

#Ve bieu do swarm
plt.figure(figsize = (16,8))
sns.histplot(x='Sepal.Width',data=df_iris,bins = 50,kde=True)
plt.xlabel("Sepal.Width",fontsize=16)
plt.xlabel('Scale',fontsize=16)
plt.ylabel('cm',fontsize=16)
plt.title('histogram of Sepal.Width',fontsize=18)
# Out:
# Text(0.5, 1.0, 'histogram of Sepal.Width')

# %%
import seaborn as sns

# Vẽ biểu đồ density
plt.figure(figsize=(16, 8))
sns.distplot(df_iris['Sepal.Width'],
             hist = True,
             bins=int(180/5),
             kde = True,
             color = 'darkblue',
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth':2})
plt.title("Density of Sepal.Width", fontsize=18)
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_14784\2997008900.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_iris['Sepal.Width'],
# Text(0.5, 1.0, 'Density of Sepal.Width')

# %%
import matplotlib.pyplot as plt

#Khoi tao grid matrix
fg,ax = plt.subplots(2,2,figsize = (16,12))

# %%
#Thong ke so luong loai hoa
x1,y1 = np.unique(df_iris['Sepal.Width'],return_counts=True)

#Sepal.Length and Sepal.Width
x2,y2 = df_iris['Sepal.Length'].values,df_iris['Sepal.Width'].values

# %%
# Khởi tạo grid matrix
fg, ax = plt.subplots(2, 2, figsize=(16, 12))

# Visualize từng biểu đồ
# Biểu đồ [0, 0]
ax[0, 0].pie(y1, labels=x1, autopct='%1.1f%%')
ax[0, 0].set_xlabel("Tỷ lệ % các loài hoa", fontsize=12)

# Biểu đồ [0, 1]
sns.heatmap(df_summary, annot=True, ax=ax[0, 1])
ax[0, 1].set_xlabel('Trung bình các measurements', fontsize=12)

# Biểu đồ [1, 0]
ax[1, 0].scatter(x2, y2)
ax[1, 0].set_xlabel('Sepal.Length', fontsize=12)
ax[1, 0].set_ylabel('Sepal.Width', fontsize=12)

# Biểu đồ [1, 1]
sns.swarmplot(data=df_iris, x='Species', y='Sepal.Width', ax=ax[1, 1])
ax[1, 1].set_xlabel('Chiều rộng đài hoa', fontsize=12)

fg.suptitle('Biểu đồ Tổng hợp', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Biểu đồ Tổng hợp')

# %%
# Import các thư viện cần thiết
import numpy as np
import matplotlib.pyplot as plt
import imageio
import os

# %%
# %%script echo skipping
# from google.colab import drive
# import os
#
# drive.mount('/content/gdrive')
# path = '/content/gdrive/My Drive/mybook'
# os.chdir(path)
#
# !rm -rf gifplot
# !mkdir gifplot
# Out:
# skipping

# %%
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    return x, y

# %%
def plot(i):
  x, y = animate(i)
  fig = plt.figure(figsize=(8, 6))
  plt.plot(x, y)
  plt.xlabel('x')
  plt.ylabel('y')
  plt.title("iteration {}".format(i))
  fig.savefig("gifplot/{:03d}.png".format(i))
  plt.close(fig)

# %%
for i in range(20):
  plot(i)
  with imageio.get_writer('mygif.gif', mode='I') as writer:
    for filename in os.listdir('gifplot'):
        image = imageio.imread('gifplot/{}'.format(filename))
        writer.append_data(image)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[40], line 2
#       1 for i in range(20):
# ----> 2   plot(i)
#       3   with imageio.get_writer('mygif.gif', mode='I') as writer:
#       4     for filename in os.listdir('gifplot'):
#
# Cell In[38], line 8, in plot(i)
#       6 plt.ylabel('y')
#       7 plt.title("iteration {}".format(i))
# ----> 8 fig.savefig("gifplot/{:03d}.png".format(i))
#       9 plt.close(fig)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# ...

# %%
from IPython.display import Image
Image(open('mygif.gif','rb').read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[41], line 2
#       1 from IPython.display import Image
# ----> 2 Image(open('mygif.gif','rb').read())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mygif.gif'

# %%
import seaborn as sns
flights = sns.load_dataset('flights')
flights.head()
df_summary = df_iris[['month','passengers']].groupby('passengers').mean()
print(df_summary)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 4
#       2 flights = sns.load_dataset('flights')
#       3 flights.head()
# ----> 4 df_summary = df_iris[['month','passengers']].groupby('passengers').mean()
#       5 print(df_summary)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
plt.figure(figsize = (16,8))
sns.lineplot(data = flights, x = 'month', y = 'passengers',marker = 'o', markersize = 10,linestyle = '-.', color = 'red')
plt.xlabel('Month',fontsize=16)
plt.ylabel('Passengers',fontsize=16)
plt.title("Average Number of Petals per Species",fontsize=18)
# Out:
# Text(0.5, 1.0, 'Average Number of Petals per Species')

# %%
plt.figure(figsize = (16,8))
plt.pie(flights['passengers'],
        labels = flights['month'],
        colors = ['green', 'red','blue'],
        autopct = '%1.1f%%',
        shadow = False)
plt.title("Average Number of Petals per Species",fontsize=18)
# Out:
# Text(0.5, 1.0, 'Average Number of Petals per Species')
